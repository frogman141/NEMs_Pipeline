# %% [markdown]
# # Loading Feature Counts and Experiment Metadata
#
# According to Helen there's an issues with the shRNAs ESRRA-1 and m35 bam files. I am not entirely sure what the issue is but i as a safety precaution we are removing them from our downstream analysis. This means we need to remove these from our feature count matrix.

# %%
require(org.Hs.eg.db, quietly = TRUE)

fc = readRDS('../data/010_lfc/hisat2.E2V2.Rds')
experiment_definitions = read.csv("../NEMpipeline/data/E2V2_experiment_definitions.csv")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '../NEMpipeline/data/E2V2_experiment_definitions.csv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("../NEMpipeline/data/E2V2_experiment_definitions.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %% [markdown]
# ## Cleaning Metadata
#
# Extracting all of the duplicate bam files from the experiment metadata and removing them from both the metadata and the count matrix generated from step 010_lfc.

# %%
# cleaning metadata
clean_metadata = experiment_definitions[!experiment_definitions$shRNA %in% c('ESRRA-1', 'm35'), ]
id = as.character(clean_metadata$Bam.File)  
id = vapply(strsplit(id,"/"),"[",4, FUN.VALUE=character(1))
id = vapply(strsplit(id,"-"),"[",2, FUN.VALUE=character(1))

# %%
# extracting bad_shRNAs bam files for shRNA ESSRA-1 and m35
bad_shRNAs = experiment_definitions[experiment_definitions$shRNA %in% c('ESRRA-1', 'm35'), ]$Bam.File
bad_shRNAs = gsub('/', '.', bad_shRNAs)
bad_shRNAs = gsub('-', '.', bad_shRNAs)
bad_shRNAs = paste0('X.mnt.scratcha.fmlab.cook01.E2V2.', bad_shRNAs)
bad_shRNAs = c("bam\\.1", bad_shRNAs)
dedup = grep(paste(bad_shRNAs, collapse="|"), colnames(fc$counts))

# %%
# clean the shRNAs
clean_metadata$shRNA = gsub('-', '_', clean_metadata$shRNA)

# %% [markdown]
# ## Cleaning Count Matrix
#
# Since where here we might as well annotate and clean the count matrix. Here i am creating new column names for the matrix and filtering out genes that fail to read the minimium expression level.

# %%
# creating a edgeR Count Matrix for downstream analysis
x = edgeR::DGEList(counts=fc$counts[,-dedup], genes=fc$annotation[,c("GeneID","Length")])

# checking all that i have the same number of ids as i do columns in my edgeR Counts Matrix
names = grep(paste(id, collapse = "|"), colnames(x$counts), value = T)
stopifnot(all.equal(names,colnames(x$counts)[1:439]))

# extracting samples using the correct names
x$counts = x$counts[,which(colnames(x$counts) %in% names)]
x$samples = x$samples[which(rownames(x$samples) %in% names),]

# %%
# Look up the gene names in the UCSC hg38 annotation
stopifnot(all.equal(as.integer(rownames(x$counts)),x$genes$GeneID))
rownames(x$counts) = x$genes$GeneID
rownames(x$counts) = annotate::lookUp(rownames(x$counts), 'org.Hs.eg', 'SYMBOL')
# Out:
# Warning message in all.equal(as.integer(rownames(x$counts)), x$genes$GeneID):
# “NAs introduced by coercion”
# Error: as.integer(rownames(x$counts)) and x$genes$GeneID are not equal:
#   'is.NA' value mismatch: 0 in current 17210 in target
# Traceback:
#
# 1. stopifnot(all.equal(as.integer(rownames(x$counts)), x$genes$GeneID))

# %%
# rename columns so they using the data more
samples_all = paste(clean_metadata$Pool, clean_metadata$Barcode, 
                 clean_metadata$Cell.line, clean_metadata$Gene, 
                 clean_metadata$shRNA, clean_metadata$Biological.Rep)

# don't overwrite samples from config
colnames(x$counts) = samples_all

# %%
expr.cutoff = 0.5

# filter out genes that don't vary by more than expr.cutoff in more than 2 experiments
keep = rowSums(edgeR::cpm(x) > expr.cutoff) >= 2
x = x[keep, , keep.lib.sizes=FALSE]

counts = x$counts

# %% [markdown]
# ## Saving Count Matrix and Metadata

# %%
counts = x$counts

# %%
write.csv(cleaned_metadata, '../data/metadata/clean_metadata.csv')
# Out:
#              SLX-17401 UDI0001 T47D SUMO2 36g B
# DDX11L1         15
# WASH7P        1659
# LOC729737     1346
# LOC102725121    14
# WASH9P        2096
# LOC100132287  1128
# LOC105378947     9
# NA           40831
# LOC100133331  1073
# LOC100288069   289
# FAM87B           3
# LINC00115       25
# LINC01128      528
# FAM41C          53
# LINC02593      243
# SAMD11         581
# NOC2L         4026
# KLHL17         281
# PLEKHN1         95
# PERM1           57
# HES4           850
# ISG15          807
# AGRN         17735
# NA              24
# LOC105378948    18
# RNF223         412
# C1orf159       670
# TNFRSF18       155
# SDF4          7259
# B3GALT6       1313
# ⋮            ⋮
# CMC4          248
# MTCP1          59
# BRCC3        2205
# VBP1         2743
# RAB39B         96
# CLIC2           8
# LOC101927830   32
# F8A2          362
# F8A3          393
# TMLHE-AS1       9
# TMLHE         693
# SPRY3         143
# VAMP7        6710
# IL9R           26
# DDX11L16       34
# NA             15
# XGY2           74
# ZFY            44
# PCDH11Y        18
# TBL1Y          24
# PRKY           28
# GYG2P1          4
# USP9Y           7
# DDX3Y         131
# UTY            15
# VCY           145
# VCY1B         135
# NLGN4Y        107
# GOLGA2P2Y      47
# GOLGA2P3Y      40
#              SLX-17401 UDI0002 T47D EP300 11ar3 D
# DDX11L1         12
# WASH7P        1324
# LOC729737     1284
# LOC102725121     9
# WASH9P        1742
# LOC100132287  1037
# LOC105378947     8
# NA           24204
# LOC100133331  1028
# LOC100288069   270
# FAM87B           3
# LINC00115       21
# LINC01128      486
# FAM41C          62
# LINC02593      158
# SAMD11         431
# NOC2L         3088
# KLHL17         212
# PLEKHN1         66
# PERM1           37
# HES4           695
# ISG15          495
# AGRN         14052
# NA              19
# LOC105378948    19
# RNF223         321
# C1orf159       642
# TNFRSF18       154
# SDF4          6462
# B3GALT6       1158
# ⋮            ⋮
# CMC4          281
# MTCP1          60
# BRCC3        2038
# VBP1         2713
# RAB39B         85
# CLIC2           3
# LOC101927830   22
# F8A2          282
# F8A3          318
# TMLHE-AS1       6
# TMLHE         605
# SPRY3         165
# VAMP7        6233
# IL9R           30
# DDX11L16       28
# NA              6
# XGY2           55
# ZFY            31
# PCDH11Y         9
# TBL1Y          15
# PRKY           34
# GYG2P1          3
# USP9Y           1
# DDX3Y         102
# UTY            10
# VCY           103
# VCY1B          97
# NLGN4Y         87
# GOLGA2P2Y      34
# GOLGA2P3Y      27
#              SLX-17401 UDI0003 T47D NR2F2 18ar3 C
# DDX11L1          5
# WASH7P        1199
# LOC729737     1257
# LOC102725121     3
# WASH9P        1562
# LOC100132287   996
# LOC105378947     0
# NA           23656
# LOC100133331   958
# LOC100288069   247
# FAM87B           3
# LINC00115       23
# LINC01128      407
# FAM41C          33
# LINC02593      134
# SAMD11         363
# NOC2L         2730
# KLHL17         169
# PLEKHN1         50
# PERM1           33
# HES4           616
# ISG15          904
# AGRN         16132
# NA              15
# LOC105378948    10
# RNF223         157
# C1orf159       554
# TNFRSF18       180
# SDF4          5806
# B3GALT6       1119
# ⋮            ⋮
# CMC4          188
# MTCP1          43
# BRCC3        1473
# VBP1         1898
# RAB39B         48
# CLIC2           2
# LOC101927830   21
# F8A2          268
# F8A3          308
# TMLHE-AS1       9
# TMLHE         499
# SPRY3         183
# VAMP7        4705
# IL9R           14
# DDX11L16       10
# NA             12
# XGY2           46
# ZFY            28
# PCDH11Y        18
# TBL1Y          21
# PRKY           37
# GYG2P1          3
# USP9Y           8
# DDX3Y         100
# UTY            14
# VCY            89
# VCY1B          77
# NLGN4Y        101
# GOLGA2P2Y      38
# GOLGA2P3Y      33
#              SLX-17401 UDI0004 T47D TRIM24 36c E
# DDX11L1         11
# WASH7P         844
# LOC729737      338
# LOC102725121     5
# WASH9P        1063
# LOC100132287   248
# LOC105378947     4
# NA           24723
# LOC100133331   236
# LOC100288069   102
# FAM87B           8
# LINC00115       15
# LINC01128      328
# FAM41C          25
# LINC02593       98
# SAMD11         277
# NOC2L         2980
# KLHL17          82
# PLEKHN1         41
# PERM1           24
# HES4           486
# ISG15          581
# AGRN         15270
# NA              12
# LOC105378948     4
# RNF223         147
# C1orf159       407
# TNFRSF18       130
# SDF4          5908
# B3GALT6        962
# ⋮            ⋮
# CMC4          221
# MTCP1          45
# BRCC3        1564
# VBP1         2540
# RAB39B         71
# CLIC2           6
# LOC101927830   22
# F8A2          260
# F8A3          308
# TMLHE-AS1       4
# TMLHE         703
# SPRY3         201
# VAMP7        6560
# IL9R           18
# DDX11L16       12
# NA              5
# XGY2           49
# ZFY            31
# PCDH11Y        24
# TBL1Y          18
# PRKY           19
# GYG2P1          2
# USP9Y          15
# DDX3Y          93
# UTY             8
# VCY           101
# VCY1B          92
# NLGN4Y         81
# GOLGA2P2Y      34
# GOLGA2P3Y      30
#              SLX-17401 UDI0005 T47D TRIM28 39b E
# DDX11L1          4
# WASH7P         746
# LOC729737      299
# LOC102725121     3
# WASH9P        1020
# LOC100132287   249
# LOC105378947     3
# NA           21331
# LOC100133331   246
# LOC100288069   109
# FAM87B           0
# LINC00115       12
# LINC01128      359
# FAM41C          43
# LINC02593       87
# SAMD11         358
# NOC2L         3162
# KLHL17         107
# PLEKHN1         53
# PERM1           36
# HES4           547
# ISG15          571
# AGRN         13414
# NA               8
# LOC105378948     6
# RNF223         399
# C1orf159       384
# TNFRSF18       146
# SDF4          5946
# B3GALT6       1081
# ⋮            ⋮
# CMC4          200
# MTCP1          31
# BRCC3        1489
# VBP1         2111
# RAB39B         82
# CLIC2           5
# LOC101927830   19
# F8A2          293
# F8A3          327
# TMLHE-AS1       2
# TMLHE         490
# SPRY3         140
# VAMP7        5394
# IL9R           18
# DDX11L16        6
# NA              7
# XGY2           44
# ZFY            38
# PCDH11Y        14
# TBL1Y          23
# PRKY           21
# GYG2P1          3
# USP9Y           7
# DDX3Y          91
# UTY             5
# VCY            52
# VCY1B          48
# NLGN4Y         84
# GOLGA2P2Y      32
# GOLGA2P3Y      23
#              SLX-17401 UDI0006 T47D CTRL Renilla C
# DDX11L1          5
# WASH7P         705
# LOC729737      293
# LOC102725121     4
# WASH9P         913
# LOC100132287   233
# LOC105378947     4
# NA           21633
# LOC100133331   234
# LOC100288069   100
# FAM87B           5
# LINC00115       13
# LINC01128      275
# FAM41C          17
# LINC02593       55
# SAMD11         268
# NOC2L         2239
# KLHL17          84
# PLEKHN1         36
# PERM1           19
# HES4           504
# ISG15          792
# AGRN         12914
# NA               9
# LOC105378948     6
# RNF223         112
# C1orf159       400
# TNFRSF18       218
# SDF4          5598
# B3GALT6        727
# ⋮            ⋮
# CMC4          198
# MTCP1          33
# BRCC3        1085
# VBP1         1868
# RAB39B         31
# CLIC2           2
# LOC101927830   14
# F8A2          163
# F8A3          187
# TMLHE-AS1       2
# TMLHE         488
# SPRY3         188
# VAMP7        4288
# IL9R            8
# DDX11L16       10
# NA              5
# XGY2           36
# ZFY            28
# PCDH11Y         6
# TBL1Y          23
# PRKY           17
# GYG2P1          1
# USP9Y           7
# DDX3Y          67
# UTY             6
# VCY            85
# VCY1B          78
# NLGN4Y         52
# GOLGA2P2Y      39
# GOLGA2P3Y      31
#              SLX-17401 UDI0007 T47D NR2F2 17ar3 A
# DDX11L1          8
# WASH7P         836
# LOC729737      265
# LOC102725121     3
# WASH9P        1110
# LOC100132287   222
# LOC105378947     2
# NA           26329
# LOC100133331   214
# LOC100288069    97
# FAM87B           4
# LINC00115       12
# LINC01128      369
# FAM41C          33
# LINC02593      111
# SAMD11         318
# NOC2L         3146
# KLHL17          90
# PLEKHN1         49
# PERM1           34
# HES4           560
# ISG15         1345
# AGRN         17367
# NA              22
# LOC105378948     8
# RNF223         262
# C1orf159       470
# TNFRSF18       162
# SDF4          6713
# B3GALT6       1172
# ⋮            ⋮
# CMC4          188
# MTCP1          41
# BRCC3        1647
# VBP1         2267
# RAB39B         72
# CLIC2           2
# LOC101927830   15
# F8A2          283
# F8A3          321
# TMLHE-AS1       4
# TMLHE         510
# SPRY3         197
# VAMP7        5680
# IL9R           20
# DDX11L16       12
# NA              2
# XGY2           40
# ZFY            44
# PCDH11Y        10
# TBL1Y          10
# PRKY           29
# GYG2P1          2
# USP9Y          10
# DDX3Y         111
# UTY            11
# VCY           172
# VCY1B         154
# NLGN4Y        130
# GOLGA2P2Y      44
# GOLGA2P3Y      39
#              SLX-17401 UDI0009 T47D NR2F2 18ar3 B
# DDX11L1          8
# WASH7P        1184
# LOC729737     1183
# LOC102725121     3
# WASH9P        1536
# LOC100132287   942
# LOC105378947     4
# NA           20688
# LOC100133331   916
# LOC100288069   250
# FAM87B           7
# LINC00115       23
# LINC01128      408
# FAM41C          51
# LINC02593      124
# SAMD11         290
# NOC2L         2884
# KLHL17         198
# PLEKHN1         73
# PERM1           47
# HES4           570
# ISG15          695
# AGRN         14035
# NA              16
# LOC105378948    21
# RNF223         144
# C1orf159       585
# TNFRSF18       160
# SDF4          6172
# B3GALT6       1112
# ⋮            ⋮
# CMC4          211
# MTCP1          54
# BRCC3        1954
# VBP1         2565
# RAB39B         69
# CLIC2           3
# LOC101927830   21
# F8A2          259
# F8A3          288
# TMLHE-AS1       4
# TMLHE         575
# SPRY3         184
# VAMP7        5802
# IL9R           24
# DDX11L16       20
# NA             11
# XGY2           37
# ZFY            26
# PCDH11Y        12
# TBL1Y          14
# PRKY           35
# GYG2P1          3
# USP9Y           5
# DDX3Y         111
# UTY            10
# VCY            75
# VCY1B          67
# NLGN4Y        121
# GOLGA2P2Y      46
# GOLGA2P3Y      40
#              SLX-17401 UDI0010 T47D FOXA1 FOXA1_2 C
# DDX11L1         11
# WASH7P         742
# LOC729737      420
# LOC102725121     7
# WASH9P         907
# LOC100132287   366
# LOC105378947     2
# NA           23906
# LOC100133331   339
# LOC100288069   108
# FAM87B           5
# LINC00115       15
# LINC01128      354
# FAM41C          38
# LINC02593      144
# SAMD11         359
# NOC2L         2961
# KLHL17          96
# PLEKHN1         78
# PERM1           48
# HES4           473
# ISG15         3275
# AGRN         22253
# NA              14
# LOC105378948     8
# RNF223         193
# C1orf159       491
# TNFRSF18       129
# SDF4          8138
# B3GALT6       1258
# ⋮            ⋮
# CMC4          214
# MTCP1          29
# BRCC3        2007
# VBP1         2263
# RAB39B         65
# CLIC2           5
# LOC101927830   16
# F8A2          279
# F8A3          309
# TMLHE-AS1       5
# TMLHE         434
# SPRY3         284
# VAMP7        5858
# IL9R           16
# DDX11L16       28
# NA             11
# XGY2           63
# ZFY            55
# PCDH11Y        13
# TBL1Y          18
# PRKY           22
# GYG2P1          3
# USP9Y           7
# DDX3Y         100
# UTY            11
# VCY           108
# VCY1B          99
# NLGN4Y         49
# GOLGA2P2Y      32
# GOLGA2P3Y      28
#              SLX-17401 UDI0011 T47D ZMIZ1 19ar3 D ⋯
# DDX11L1          5                                ⋯
# WASH7P        1010                                ⋯
# LOC729737      458                                ⋯
# LOC102725121     5                                ⋯
# WASH9P        1275                                ⋯
# LOC100132287   400                                ⋯
# LOC105378947     1                                ⋯
# NA           28429                                ⋯
# LOC100133331   376                                ⋯
# LOC100288069   135                                ⋯
# FAM87B           8                                ⋯
# LINC00115       14                                ⋯
# LINC01128      400                                ⋯
# FAM41C          43                                ⋯
# LINC02593      127                                ⋯
# SAMD11         424                                ⋯
# NOC2L         3788                                ⋯
# KLHL17         132                                ⋯
# PLEKHN1         63                                ⋯
# PERM1           33                                ⋯
# HES4           716                                ⋯
# ISG15          718                                ⋯
# AGRN         19993                                ⋯
# NA               4                                ⋯
# LOC105378948     6                                ⋯
# RNF223         190                                ⋯
# C1orf159       552                                ⋯
# TNFRSF18       133                                ⋯
# SDF4          7470                                ⋯
# B3GALT6       1255                                ⋯
# ⋮            ⋮                                    ⋱
# CMC4          193                                 ⋯
# MTCP1          26                                 ⋯
# BRCC3        1644                                 ⋯
# VBP1         2397                                 ⋯
# RAB39B         49                                 ⋯
# CLIC2           1                                 ⋯
# LOC101927830   17                                 ⋯
# F8A2          252                                 ⋯
# F8A3          284                                 ⋯
# TMLHE-AS1       2                                 ⋯
# TMLHE         549                                 ⋯
# SPRY3         197                                 ⋯
# VAMP7        6782                                 ⋯
# IL9R           22                                 ⋯
# DDX11L16       12                                 ⋯
# NA              7                                 ⋯
# XGY2           55                                 ⋯
# ZFY            48                                 ⋯
# PCDH11Y        12                                 ⋯
# TBL1Y          26                                 ⋯
# PRKY           26                                 ⋯
# GYG2P1          4                                 ⋯
# USP9Y           8                                 ⋯
# DDX3Y         120                                 ⋯
# UTY             8                                 ⋯
# VCY           175                                 ⋯
# VCY1B         146                                 ⋯
# NLGN4Y         98                                 ⋯
# GOLGA2P2Y      42                                 ⋯
# GOLGA2P3Y      37                                 ⋯
#              SLX-18070 UDI0077 MCF7 RARA 7b E
# DDX11L1         15
# WASH7P         596
# LOC729737      764
# LOC102725121     6
# WASH9P         803
# LOC100132287   654
# LOC105378947    21
# NA           13596
# LOC100133331   601
# LOC100288069    95
# FAM87B           9
# LINC00115       17
# LINC01128      180
# FAM41C          19
# LINC02593      137
# SAMD11         495
# NOC2L         2300
# KLHL17          95
# PLEKHN1        112
# PERM1           30
# HES4           395
# ISG15          638
# AGRN          5896
# NA              12
# LOC105378948    17
# RNF223         206
# C1orf159       305
# TNFRSF18       171
# SDF4          3584
# B3GALT6        428
# ⋮            ⋮
# CMC4          187
# MTCP1          28
# BRCC3        1745
# VBP1         2322
# RAB39B        138
# CLIC2          17
# LOC101927830   19
# F8A2          393
# F8A3          442
# TMLHE-AS1       7
# TMLHE         590
# SPRY3         173
# VAMP7        4860
# IL9R           22
# DDX11L16       32
# NA              1
# XGY2           11
# ZFY            21
# PCDH11Y        20
# TBL1Y          32
# PRKY          128
# GYG2P1         11
# USP9Y           2
# DDX3Y          58
# UTY             5
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      18
# GOLGA2P3Y      14
#              SLX-18070 UDI0078 MCF7 FOXA1 FOXA1_1 B
# DDX11L1         24
# WASH7P         656
# LOC729737      785
# LOC102725121    13
# WASH9P         868
# LOC100132287   691
# LOC105378947    27
# NA           18384
# LOC100133331   615
# LOC100288069    82
# FAM87B           4
# LINC00115       16
# LINC01128      193
# FAM41C          18
# LINC02593      225
# SAMD11         620
# NOC2L         2407
# KLHL17         140
# PLEKHN1         80
# PERM1           47
# HES4           308
# ISG15          775
# AGRN          8472
# NA               4
# LOC105378948    18
# RNF223         173
# C1orf159       300
# TNFRSF18       169
# SDF4          3921
# B3GALT6        559
# ⋮            ⋮
# CMC4          217
# MTCP1          33
# BRCC3        1799
# VBP1         2520
# RAB39B        133
# CLIC2          14
# LOC101927830   23
# F8A2          408
# F8A3          449
# TMLHE-AS1       7
# TMLHE         728
# SPRY3         192
# VAMP7        5136
# IL9R           14
# DDX11L16       50
# NA              2
# XGY2           18
# ZFY            35
# PCDH11Y        52
# TBL1Y          10
# PRKY          109
# GYG2P1          0
# USP9Y           2
# DDX3Y          52
# UTY             6
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      18
# GOLGA2P3Y      15
#              SLX-18070 UDI0079 MCF7 DPF2 27a D
# DDX11L1         17
# WASH7P         597
# LOC729737      605
# LOC102725121     9
# WASH9P         801
# LOC100132287   513
# LOC105378947    22
# NA           13073
# LOC100133331   467
# LOC100288069    72
# FAM87B           8
# LINC00115       10
# LINC01128      138
# FAM41C          15
# LINC02593      197
# SAMD11         628
# NOC2L         2390
# KLHL17         118
# PLEKHN1        136
# PERM1           41
# HES4           346
# ISG15         2047
# AGRN          7133
# NA              17
# LOC105378948    10
# RNF223         195
# C1orf159       263
# TNFRSF18       154
# SDF4          4028
# B3GALT6        470
# ⋮            ⋮
# CMC4          185
# MTCP1          27
# BRCC3        1726
# VBP1         2307
# RAB39B        164
# CLIC2          10
# LOC101927830   21
# F8A2          398
# F8A3          437
# TMLHE-AS1      12
# TMLHE         621
# SPRY3         177
# VAMP7        4744
# IL9R            4
# DDX11L16       30
# NA              2
# XGY2           18
# ZFY            23
# PCDH11Y        26
# TBL1Y          19
# PRKY          118
# GYG2P1          3
# USP9Y           2
# DDX3Y          44
# UTY             6
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      19
# GOLGA2P3Y      17
#              SLX-18070 UDI0089 MCF7 TRIM24 25c B
# DDX11L1         29
# WASH7P         769
# LOC729737      851
# LOC102725121     8
# WASH9P        1004
# LOC100132287   724
# LOC105378947    44
# NA           15646
# LOC100133331   699
# LOC100288069   116
# FAM87B           8
# LINC00115        8
# LINC01128      261
# FAM41C          17
# LINC02593      182
# SAMD11         503
# NOC2L         2595
# KLHL17         141
# PLEKHN1        141
# PERM1           46
# HES4           318
# ISG15          549
# AGRN          8355
# NA              15
# LOC105378948    10
# RNF223         259
# C1orf159       345
# TNFRSF18       155
# SDF4          4013
# B3GALT6        477
# ⋮            ⋮
# CMC4          238
# MTCP1          26
# BRCC3        2206
# VBP1         2822
# RAB39B        156
# CLIC2          10
# LOC101927830   25
# F8A2          372
# F8A3          401
# TMLHE-AS1       3
# TMLHE         795
# SPRY3         262
# VAMP7        6281
# IL9R           22
# DDX11L16       54
# NA              0
# XGY2           13
# ZFY            37
# PCDH11Y        66
# TBL1Y          36
# PRKY          197
# GYG2P1          2
# USP9Y          10
# DDX3Y          57
# UTY             7
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      22
# GOLGA2P3Y      25
#              SLX-18070 UDI0090 MCF7 FOXA1 FOXA1_1 D
# DDX11L1         30
# WASH7P         761
# LOC729737      917
# LOC102725121    11
# WASH9P         993
# LOC100132287   746
# LOC105378947    37
# NA           19510
# LOC100133331   715
# LOC100288069   100
# FAM87B          14
# LINC00115       10
# LINC01128      212
# FAM41C          22
# LINC02593      259
# SAMD11         739
# NOC2L         2833
# KLHL17         115
# PLEKHN1        121
# PERM1           50
# HES4           292
# ISG15          709
# AGRN         11053
# NA              17
# LOC105378948    20
# RNF223         184
# C1orf159       324
# TNFRSF18       150
# SDF4          4242
# B3GALT6        584
# ⋮            ⋮
# CMC4          229
# MTCP1          32
# BRCC3        2401
# VBP1         2753
# RAB39B        212
# CLIC2          11
# LOC101927830   24
# F8A2          423
# F8A3          467
# TMLHE-AS1       6
# TMLHE         863
# SPRY3         267
# VAMP7        6432
# IL9R           20
# DDX11L16       60
# NA              4
# XGY2           25
# ZFY            40
# PCDH11Y        81
# TBL1Y          49
# PRKY          151
# GYG2P1          6
# USP9Y           2
# DDX3Y          91
# UTY             7
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      24
# GOLGA2P3Y      20
#              SLX-18070 UDI0091 MCF7 GATA3 29k B
# DDX11L1         19
# WASH7P         762
# LOC729737      931
# LOC102725121    12
# WASH9P         999
# LOC100132287   763
# LOC105378947    23
# NA           13376
# LOC100133331   744
# LOC100288069   117
# FAM87B           6
# LINC00115       19
# LINC01128      233
# FAM41C          14
# LINC02593      230
# SAMD11         658
# NOC2L         2705
# KLHL17         154
# PLEKHN1        150
# PERM1           66
# HES4           445
# ISG15          604
# AGRN          8568
# NA              19
# LOC105378948    12
# RNF223         268
# C1orf159       346
# TNFRSF18       218
# SDF4          4771
# B3GALT6        481
# ⋮            ⋮
# CMC4          209
# MTCP1          35
# BRCC3        2200
# VBP1         2685
# RAB39B        119
# CLIC2          12
# LOC101927830   26
# F8A2          381
# F8A3          433
# TMLHE-AS1       8
# TMLHE         733
# SPRY3         191
# VAMP7        5794
# IL9R           14
# DDX11L16       46
# NA              1
# XGY2            8
# ZFY            43
# PCDH11Y        57
# TBL1Y          31
# PRKY          158
# GYG2P1          3
# USP9Y           2
# DDX3Y          73
# UTY             5
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      27
# GOLGA2P3Y      25
#              SLX-18070 UDI0092 MCF7 GRHL2 38fr3 B
# DDX11L1         13
# WASH7P         768
# LOC729737      958
# LOC102725121     6
# WASH9P         987
# LOC100132287   754
# LOC105378947    32
# NA           14612
# LOC100133331   747
# LOC100288069    91
# FAM87B          10
# LINC00115       21
# LINC01128      193
# FAM41C          25
# LINC02593      266
# SAMD11         717
# NOC2L         2702
# KLHL17         149
# PLEKHN1        159
# PERM1           51
# HES4           384
# ISG15         1139
# AGRN          9166
# NA              14
# LOC105378948    14
# RNF223         163
# C1orf159       294
# TNFRSF18       155
# SDF4          3954
# B3GALT6        476
# ⋮            ⋮
# CMC4          204
# MTCP1          24
# BRCC3        1891
# VBP1         2528
# RAB39B        183
# CLIC2          14
# LOC101927830   37
# F8A2          491
# F8A3          538
# TMLHE-AS1      14
# TMLHE         830
# SPRY3         232
# VAMP7        5140
# IL9R           22
# DDX11L16       34
# NA              9
# XGY2           25
# ZFY            27
# PCDH11Y        30
# TBL1Y          31
# PRKY          165
# GYG2P1          2
# USP9Y           4
# DDX3Y          79
# UTY             4
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      30
# GOLGA2P3Y      28
#              SLX-18070 UDI0094 MCF7 EP300 11ar3 C
# DDX11L1         11
# WASH7P         748
# LOC729737     1025
# LOC102725121     4
# WASH9P         979
# LOC100132287   790
# LOC105378947    43
# NA           15698
# LOC100133331   785
# LOC100288069   129
# FAM87B          12
# LINC00115       14
# LINC01128      226
# FAM41C          19
# LINC02593      269
# SAMD11         654
# NOC2L         2068
# KLHL17         145
# PLEKHN1        121
# PERM1           31
# HES4           342
# ISG15         1500
# AGRN          6598
# NA              15
# LOC105378948    13
# RNF223         112
# C1orf159       290
# TNFRSF18        71
# SDF4          3753
# B3GALT6        471
# ⋮            ⋮
# CMC4          351
# MTCP1          44
# BRCC3        1992
# VBP1         2697
# RAB39B        368
# CLIC2          31
# LOC101927830   31
# F8A2          371
# F8A3          415
# TMLHE-AS1       8
# TMLHE         845
# SPRY3         263
# VAMP7        6040
# IL9R           12
# DDX11L16       34
# NA              5
# XGY2           32
# ZFY            38
# PCDH11Y        23
# TBL1Y          27
# PRKY          203
# GYG2P1          5
# USP9Y           1
# DDX3Y          50
# UTY             4
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      19
# GOLGA2P3Y      17
#              SLX-18070 UDI0095 MCF7 CTRL Renilla B
# DDX11L1         23
# WASH7P         889
# LOC729737     1158
# LOC102725121    14
# WASH9P        1159
# LOC100132287   946
# LOC105378947    31
# NA           17978
# LOC100133331   939
# LOC100288069   130
# FAM87B          13
# LINC00115       10
# LINC01128      208
# FAM41C          19
# LINC02593      295
# SAMD11         726
# NOC2L         2818
# KLHL17         190
# PLEKHN1        156
# PERM1           59
# HES4           304
# ISG15          962
# AGRN         10416
# NA              25
# LOC105378948    20
# RNF223         161
# C1orf159       337
# TNFRSF18       127
# SDF4          4146
# B3GALT6        534
# ⋮            ⋮
# CMC4          255
# MTCP1          41
# BRCC3        2284
# VBP1         2687
# RAB39B        242
# CLIC2          18
# LOC101927830   43
# F8A2          413
# F8A3          464
# TMLHE-AS1      15
# TMLHE         891
# SPRY3         251
# VAMP7        5783
# IL9R           18
# DDX11L16       52
# NA              5
# XGY2           15
# ZFY            44
# PCDH11Y        25
# TBL1Y          44
# PRKY          182
# GYG2P1          5
# USP9Y           7
# DDX3Y          84
# UTY            12
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      30
# GOLGA2P3Y      27
#              SLX-18070 UDI0096 MCF7 TRIM33 13cr3 C
# DDX11L1         23
# WASH7P         767
# LOC729737      774
# LOC102725121     9
# WASH9P        1005
# LOC100132287   617
# LOC105378947    40
# NA           14569
# LOC100133331   580
# LOC100288069    99
# FAM87B          10
# LINC00115       16
# LINC01128      254
# FAM41C          26
# LINC02593      209
# SAMD11         675
# NOC2L         2605
# KLHL17         139
# PLEKHN1        148
# PERM1           54
# HES4           372
# ISG15          677
# AGRN          7462
# NA              16
# LOC105378948    15
# RNF223         312
# C1orf159       386
# TNFRSF18       197
# SDF4          4118
# B3GALT6        559
# ⋮            ⋮
# CMC4          246
# MTCP1          32
# BRCC3        2217
# VBP1         2798
# RAB39B        148
# CLIC2          10
# LOC101927830   16
# F8A2          390
# F8A3          425
# TMLHE-AS1       2
# TMLHE         742
# SPRY3         200
# VAMP7        5552
# IL9R           34
# DDX11L16       56
# NA              4
# XGY2           20
# ZFY            37
# PCDH11Y        79
# TBL1Y          29
# PRKY          186
# GYG2P1          2
# USP9Y           1
# DDX3Y          57
# UTY             8
# VCY             0
# VCY1B           0
# NLGN4Y          0
# GOLGA2P2Y      17
# GOLGA2P3Y      16
